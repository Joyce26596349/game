// %% [markdown]
// # 🎲 猜數字遊戲

// %%
#include <iostream>
#include <ctime>
#include <cstdlib>

using namespace std;

int main() {
    while(true) {
        srand(time(NULL));
        int num = rand() % 100 + 1;
        int low = 1, high = 100;
        cout << "這是一個猜數字遊戲，跟據系統提示猜出正確數字吧" << endl;
        cout << "輸入 0 結束遊戲，輸入 1111 結束此輪" << endl;
        int input;
        int count = 0;
        
        while (true) {
            cout << "請輸入 " << low << " ~ " << high << " 之間的數: ";
            if (!(cin >> input)) break;
            
            if (input == 0) return 0;
            if (input == 1111) break;
            
            if (low > input || high < input) {
                cout << "輸入錯誤！" << endl;
                continue;
            }
            
            count += 1;
            if (num > input) {
                cout << "再大" << endl;
                low = input;
            } else if (num < input) {
                cout << "再小" << endl;
                high = input;
            } else {
                cout << "恭喜猜中" << endl;
                cout << "你猜了 " << count << " 次" << endl;
                break;
            }
        }
        cout << "數字為:" << num << endl;
    }
    return 0;
}
